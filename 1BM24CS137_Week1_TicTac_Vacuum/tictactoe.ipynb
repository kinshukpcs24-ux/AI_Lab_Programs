# %% [markdown]
# <a href="https://colab.research.google.com/github/kinshukpcs24-ux/AI_Lab_Programs/blob/main/1BM24CS137_Week1_TicTac_Vacuum/tictactoe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check(B):
    if B[0][0]==B[0][1] and B[0][0]==B[0][2]:
        return B[0][0]
    elif B[1][0]==B[1][1] and B[1][0]==B[1][2]:
        return B[1][0]
    elif B[2][0]==B[2][1] and B[2][0]==B[2][2]:
        return B[2][0]
    elif B[0][0]==B[1][0] and B[1][0]==B[2][0]:
        return B[0][0]
    elif B[0][1]==B[1][1] and B[1][1]==B[2][1]:
        return B[0][1]
    elif B[0][2]==B[1][2] and B[1][2]==B[2][2]:
        return B[0][2]
    elif B[0][0]==B[1][1] and B[1][1]==B[2][2]:
        return B[0][0]
    elif B[0][2]==B[1][1] and B[1][1]==B[2][0]:
        return B[0][2]
    else:
        return 'N'

def play(player,B):
    x = int(input("Enter x position : "))
    y = int(input("Enter y position : "))
    if B[x-1][y-1] == 'E':
        B[x-1][y-1] = player
    else:
        print("Position occupied! Enter position again")
        play(player,B)

def display(B):
    print(f" {B[0][0]} | {B[0][1]} | {B[0][2]}")
    print(" ---------")
    print(f" {B[1][0]} | {B[1][1]} | {B[1][2]}")
    print(" ---------")
    print(f" {B[2][0]} | {B[2][1]} | {B[2][2]}")

B = [['E','E','E'],['E','E','E'],['E','E','E']]

current = input("1st player (X or O) : ")

for i in range(9):
    display(B)
    print(f"\nPlayer {current}'s Turn")
    play(current,B)
    check_output = check(B)
    if check_output == 'X' or check_output == 'O':
        display(B)
        print(f"Player {current} wins!")
        break
    if current == 'X':
        current = 'O'
    elif current == 'O':
        current = 'X'

if check(B) == 'N':
    display(B)
    print("Game is a draw!")
# Out:
# 1st player (X or O) : X
#  E | E | E
#  ---------
#  E | E | E
#  ---------
#  E | E | E
#
# Player X's Turn
# Enter x position : 1
# Enter y position : 1
#  X | E | E
#  ---------
#  E | E | E
#  ---------
#  E | E | E
#
# Player O's Turn
# Enter x position : 1
# Enter y position : 2
#  X | O | E
#  ---------
#  E | E | E
#  ---------
#  E | E | E
#
# Player X's Turn
# Enter x position : 2
# Enter y position : 2
#  X | O | E
#  ---------
#  E | X | E
#  ---------
#  E | E | E
#
# Player O's Turn
# Enter x position : 3
# Enter y position : 3
#  X | O | E
#  ---------
#  E | X | E
#  ---------
#  E | E | O
#
# Player X's Turn
# Enter x position : 2
# Enter y position : 1
#  X | O | E
#  ---------
#  X | X | E
#  ---------
#  E | E | O
#
# Player O's Turn
# Enter x position : 3
# Enter y position : 1
#  X | O | E
#  ---------
#  X | X | E
#  ---------
#  O | E | O
#
# Player X's Turn
# Enter x position : 2
# Enter y position : 3
#  X | O | E
#  ---------
#  X | X | X
#  ---------
#  O | E | O
# Player X wins!
